# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
_ = plt.plot(x, y, color='coral', linestyle='--')
_ = plt.plot(x, z, color='yellowgreen', linestyle='-.')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
_ = fig, ax = plt.subplots(1,2)
_ = ax[0].plot(x, y, color='coral', linestyle='--')
_ = ax[1].plot(x, z, color='yellowgreen', linestyle='-.')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
_ = fig, ax = plt.subplots(1,2, figsize=(12,8))
_ = fig.suptitle('Subplot', fontsize='20', fontweight='bold')
_ = ax[0].plot(x, y, color='coral', linestyle='--')
_ = ax[0].set_title('x-y', fontsize='15')
_ = ax[0].set_xlabel('x', fontsize='10')
_ = ax[0].set_ylabel('y', fontsize='10')
_ = ax[1].plot(x, z, color='yellowgreen', linestyle='-.')
_ = ax[1].set_title('x-z', fontsize='15')
_ = ax[1].set_xlabel('x', fontsize='10')
_ = ax[1].set_ylabel('z', fontsize='10')

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
a = np.exp(x)

# %%
_ = plt.plot(x,z)
_ = plt.plot(x,a)

# %%
fig, ax = plt.subplots()
_ = ax.plot(x,z)
_ = ax.plot(x,a)
ax.set_xscale('log')
ax.set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, ax = plt.subplots()
_ = ax.plot(x,z, label='y = x^2')
_ = ax.plot(x,a, label='y = e^x')
ax.set_xscale('log')
ax.set_yscale('log')
_ = ax.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../../../notebooks/data/Fitbit2.csv')

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
steps_by_month = fitbit.groupby('Months_encoded')['Steps'].median()
steps_by_month
# Out:
# Months_encoded
# 1     10366.0
# 2      8966.0
# 3     11122.0
# 4     13846.5
# 5     11998.0
# 6     12935.5
# 7     10644.0
# 8     12213.0
# 9      9343.0
# 10     7865.0
# 11     9453.5
# 12     8531.0
# Name: Steps, dtype: float64

# %%
fitbit[['Days','Work_or_Weekend']]
# Out:
#           Days  Work_or_Weekend
# 0       Friday                1
# 1     Saturday                0
# 2       Sunday                0
# 3       Monday                1
# 4      Tuesday                1
# ..         ...              ...
# 362    Tuesday                1
# 363  Wednesday                1
# 364   Thursday                1
# 365     Friday                1
# 366   Saturday                0
#
# [366 rows x 2 columns]

# %%
steps_by_day = fitbit.groupby('Work_or_Weekend')['Steps'].median().rename({0:'Weekend', 1:'Workday'})
steps_by_day
# Out:
# Work_or_Weekend
# Weekend     9998
# Workday    10457
# Name: Steps, dtype: int64

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
fig.suptitle('Steps', fontsize='18', fontweight='bold')

# MEDIAN STEPS BY MONTH_ENCODED
# your code here
_ = plt.sca(ax[0])
_ = steps_by_month.plot(ax=ax[0])
_ = ax[0].set_xticks(range(1,13))
_ = ax[0].set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
_ = ax[0].set_xlabel('Months')
_ = ax[0].set_ylabel('Steps')
_ = ax[0].set_title('Steps by month', fontsize='13', fontweight='bold')

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
_ = plt.sca(ax[1])
_ = steps_by_day.plot(kind='bar', ax=ax[1])
_ = ax[1].set_xticklabels(['Weekend','Workday'], rotation='horizontal')
_ = ax[1].set_xlabel('')
_ = ax[1].set_ylabel('Steps')
_ = ax[1].set_title('Steps by day', fontsize='13', fontweight='bold')
_ = ax[1].set_ylim(0,14000)

# SUBPLOT FINAL SETTINGS
fig.tight_layout()
fig.savefig('../figures/Steps.jpg')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fig, ax = plt.subplots(1,3, figsize=(12,6))
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for ax, feature in zip(ax, features):
    plt.sca(ax)
    plt.scatter(fitbit['Steps'], fitbit[feature])
    plt.xlabel(feature, fontsize='12', fontweight='bold')
    plt.ylabel('Steps')

fig.suptitle('Steps by minutes', fontsize='18', fontweight='bold')
fig.tight_layout()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../../../notebooks/data/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
numerical = titanic.select_dtypes(include='number')
numerical.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
# CATEGORICAL VARIABLES
# your code here
categorical = titanic.select_dtypes(exclude='number')
categorical.dtypes
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.rcParams['figure.figsize'] = (12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
_ = titanic['Age'].hist()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, ax = plt.subplots(1,3)
_ = ax[0].hist(titanic['Age'], bins = 10)
_ = ax[1].hist(titanic['Age'], bins = 20)
_ = ax[2].hist(titanic['Age'], bins = 50)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bigger the bin, the more data accuracy.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
_ = sns.displot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
_ = titanic['Sex'].value_counts().plot(kind='bar')

# %%
# Method 2 - seaborn
# your code here
_ = sns.countplot(data=titanic, x='Sex')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
_ = sns.countplot(data=titanic, x='Pclass')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
_ = sns.catplot(data=titanic, y='Age', kind='box')

# %%
"""
Boxplot
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The average age was around 29 years.
25% of the total passengers were less of 20 years, and 25% older than 38 years.
This means, 50% of the total passengers of the Titanic were between 20 an 38 years old.
There are a few outliers over the maximum age, but no outliers below the minimum age.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
_ = sns.catplot(data=titanic, y='Age', kind='violin')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The distribution of the total passengers of the Titanic according to their age. 
We can observe the bigger number of passengers were around 29 years, something we already observed with the boxplot.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
_ = plt.scatter(titanic['Fare'], titanic['Age'])

# %%
# Method 2 - seaborn
# your code here
_ = sns.relplot(data=titanic, x='Fare', y='Age', kind='scatter')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
_ = sns.heatmap(titanic.corr(), cmap='Blues', annot=True)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
We can observe a correlation between the number of Siblings/Spouses abroad (SibSp) and the number of Parent and Children abroad (Parch)
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
_ = sns.catplot(data=titanic, y='Age', x='Pclass', kind='box')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
_ = sns.catplot(data=titanic, x='Sex', y='Age', kind='swarm')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
